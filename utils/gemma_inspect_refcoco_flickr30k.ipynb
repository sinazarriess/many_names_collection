# %%
import pandas as pd

# %% [markdown]
# ### RefCOCO or Flickr30k

# %%
#dataset = "refcoco"
dataset = "flickr30k"

# %%
annodf = pd.read_json("../data/%s_anno-dep-pos-wn-attr.json.gz" % dataset, compression='gzip', orient='split')

# %%
annodf
# Out:
#           image_id  region_id  \
# 0       3631986552     132816
# 1       3631986552     132817
# 2       3631986552     132821
# 3       3631986552     132816
# 4       3631986552     132817
# 5       3631986552     132818
# 6       3631986552     132816
# 7       3631986552     132817
# 8       3631986552     132816
# 9       3631986552     132817
# 10      3631986552     132816
# 11      3631986552     132818
# 12      3631986552     132820
# 13      1000092795          1
# 14      1000092795          2
# 15      1000092795          3
# 16      1000092795          8
# 17      1000092795          1
# 18      1000092795          4
# 19      1000092795          1
# 20      1000092795          5
# 21      1000092795          9
# 22      1000092795          6
# 23      1000092795          7
# 24      1000092795          9
# 25      1000092795          1
# 26      1000092795         10
# 27        10002456         11
# 28        10002456         12
# 29        10002456         13
# ...

# %%
reg_distr_def = pd.read_json("../data/%s_regions_distractors.json.gz" % dataset, compression='gzip', orient='split')

# %%
reg_distr_def
# Out:
#                                           distractor_cats  \
# 0       [person, person, person, person, person, perso...
# 1       [person, person, person, person, person, perso...
# 2       [person, person, person, person, person, perso...
# 3       [person, person, person, person, person, perso...
# 4       [person, person, person, person, person, perso...
# 5       [person, person, person, person, person, perso...
# 6       [group, person, person, motion, group, artifac...
# 7       [person, person, person, person, person, motio...
# 8       [person, person, person, group, group, artifac...
# 9       [person, person, person, group, person, person...
# 10      [person, person, person, group, person, person...
# 11      [person, person, person, group, person, person...
# 12      [person, person, person, group, person, person...
# 13      [person, person, person, group, person, person...
# 14      [person, person, artifact, person, person, art...
# ...
