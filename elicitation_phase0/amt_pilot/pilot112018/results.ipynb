# %%
import pandas as pd
from collections import Counter

# %%
rdf = pd.read_csv("Batch_3451914_batch_results.csv")

# %%
rdf[['Input.taboolist_0','Answer.inputbox_objname-0']]
# Out:
# ['Input.taboolist_0', 'Answer.inputbox_objname-0']

# %%
im2taboo = {}

for ix in ['0','1','2','3','4']:
    images = set(rdf['Input.img_%s_url'%ix])
    print("Images:",len(images))
    for im in images:
        print(im)
        imdf = rdf[rdf['Input.img_%s_url'%ix] == im]
        taboos = set(imdf['Input.taboolist_%s'%ix])
        if len(taboos) > 0:
            names = Counter([x.lower() for x in imdf['Answer.inputbox_objname-%s'%ix] if x != '{}'])
            names = Counter({n:names[n] for n in names if (names[n] > 1) and not (n in taboos)})
           
            if len(names) > 0:
                most_common = names.most_common(1)[0][0]
                taboos = list(taboos)
                taboos.append(most_common)
           
            print("Taboos:",taboos)
            print("Names:",names)
            im2taboo[im] = taboos
# Out:
# Images: 12
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2373189_733918_ambiguous_synset.png
# Taboos: ['dishes', 'measuring cup']
# Names: Counter({'measuring cup': 3})
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2393207_3218440_ambiguous_synset.png
# Taboos: ['donut', 'pastry']
# Names: Counter({'pastry': 3})
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2348563_1842485_singleton_category.png
# Taboos: ['sandwich', 'sub']
# Names: Counter({'sub': 2})
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2351945_3004860_singleton_obj.png
# Taboos: ['apartments', 'building']
# Names: Counter({'building': 4, 'buildings': 2})
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2348287_883426_ambiguous_synset.png
# Taboos: ['tools', 'scissor']
# Names: Counter({'scissor': 3, 'blades': 2})
# http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2381209_706387_singleton_category.png
# ...

# %%
taboo2names
# Out:
# {'rice': ['food', 'food', 'starch', 'grain', '{}', 'grains', 'grain'],
#  'apartments': ['bulding',
#   'buildings',
#   'building',
#   'building',
#   'building',
#   'flat',
#   'window',
#   'mirror',
#   'building',
#   'buildings'],
#  'pug': ['dog', 'dog', 'dog', 'dog', '{}', 'dog', 'dog', 'dog', 'dog', 'dog'],
#  'donut': ['cake',
#   'pastry',
#   'dish',
#   'dessert',
#   'sweet dish',
#   'sweet',
#   'pastry',
#   'pastry',
#   '{}'],
#  'puppy': ['animal',
#   'sniffing',
#   'dog',
#   'dog',
#   'dog',
#   'dog',
#   'dog',
#   'dog',
#   'dogling',
#   'collar belt'],
#  'dishes': ['spoon',
#   'measuring cup',
#   '{}',
#   'measuring cup',
#   'cup',
#   'measuring cup',
#   'soup',
#   '{}',
#   'vessel',
#   'measurer'],
#  'dish': ['breakfast',
#   'plate',
#   'egg scramble',
#   'plate',
#   '{}',
#   'eggs benedict',
#   'plate',
#   'food',
#   '{}'],
#  'huts': ['shed',
#   'beach',
#   'tent',
#   'beach umbrella',
#   'chair',
#   'shades',
#   'beach',
# ...

# %%
len(taboo2names)
# Out:
# 59

# %%
len(set(rdf['WorkerId']))
# Out:
# 45

# %%
120/45
# Out:
# 2.6666666666666665

# %%
im2taboo
# Out:
# {'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2319541_2810174_singleton_category.png': 'cup',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2325122_3456054_ambiguous_category.png': 'garage',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2332727_3337741_ambiguous_category.png': 'pizza',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2335655_2105998_ambiguous_synset.png': 'dog',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2338246_3491340_ambiguous_category.png': 'player',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2338898_2232134_singleton_obj.png': 'biker',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2339579_2625157_ambiguous_category.png': 'umbrella',
#  'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2341515_3654782_ambiguous_synset.png': 'beach',
# ...

# %%
rdf.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.img_0_url',
#        'Input.img_1_url', 'Input.img_2_url', 'Input.img_3_url',
#        'Input.img_4_url', 'Input.taboolist_0', 'Input.taboolist_1',
#        'Input.taboolist_2', 'Input.taboolist_3', 'Input.taboolist_4',
#        'Answer.comments', 'Answer.inputbox_objname-0',
#        'Answer.inputbox_objname-1', 'Answer.inputbox_objname-2',
#        'Answer.inputbox_objname-3', 'Answer.inputbox_objname-4',
# ...

# %%
"ashg".lower()
# Out:
# 'ashg'

# %%
rdf.iloc[51]
# Out:
# HITId                                             32LAQ1JNTAUK9UFZ405UGMPT4ZBUT5
# HITTypeId                                         3EOS91U1V0GLK8D687GF4TICMDMBYN
# Title                                                                  YouNameIt
# Description                    Please view an image and provide a name for on...
# Keywords                                             image, name, picture, photo
# Reward                                                                     $0.20
# CreationTime                                        Wed Nov 28 03:12:11 PST 2018
# MaxAssignments                                                                10
# RequesterAnnotation             BatchId:3451914;OriginalHitTemplateId:862366346;
# AssignmentDurationInSeconds                                                  600
# AutoApprovalDelayInSeconds                                                259200
# Expiration                                          Wed Dec 05 03:12:11 PST 2018
# ...

# %%
batchdf = pd.read_csv("pilot-amt_table.csv")

# %%
batchdf.iloc[0]['img_0_url']
# Out:
# 'http://www.coli.uni-saarland.de/~carina/object_naming/amt_images/2384848_1304092_ambiguous_category.png'

# %%
rdf.t

# %%
rdf2 = pd.read_csv("Batch_3452735_batch_results.csv")
rdf3 = pd.read_csv("Batch_3453438_batch_results.csv")

# %%
workers2 = set(rdf2['WorkerId'])
workers1 = set(rdf['WorkerId'])
workers3 = set(rdf3['WorkerId'])

# %%
len(workers2)
# Out:
# 47

# %%
len(workers1)
# Out:
# 45

# %%
len(workers3)
# Out:
# 41

# %%
len(workers1 | workers2)
# Out:
# 89

# %%
len(workers1 | workers2 | workers3)
# Out:
# 120

# %%
len(workers1 | workers3)
# Out:
# 77

# %%
len(workers2 | workers3)
# Out:
# 86

# %%
40/110
# Out:
# 0.36363636363636365

# %%
rdf2[['WorkerId','Answer.inputbox_objname-1','Input.taboolist_1']][60:100]
# Out:
#           WorkerId Answer.inputbox_objname-1 Input.taboolist_1
# 60   AGLY8XF1SIZSV       box containing food            cereal
# 61  A3KNHT45R16NM8                       BOX            cereal
# 62   A49A0FF6ZXYDU                       box            cereal
# 63  A19TQ1VHUUZ7AI                       box            cereal
# 64  A3CA7SCTM4H9IO                    cereal            cereal
# 65  A14OPFM8OFA4WF                        {}            cereal
# 66  A3ADP5EDYSB9HD                       box            cereal
# 67  A3DZKMHB7MPQ6L                 BREAKFAST            cereal
# 68  A18XIQBTQWMWF1                    cereal            cereal
# 69   AE4P5KVUE9HST                 Breakfast            cereal
# 70  A3C2DKCZLI304P                   UTILITY    tools, scissor
# 71   A7Z9TZUO1A3CZ                     blade    tools, scissor
# 72  A1N4P4XGQM7NXE                  stabbies    tools, scissor
# 73   AGLY8XF1SIZSV               sharp items    tools, scissor
# ...

# %%
rdf_all = pd.concat([rdf,rdf2])

# %%
rdf_all
# Out:
#                               HITId                       HITTypeId  \
# 0    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 1    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 2    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 3    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 4    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 5    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 6    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 7    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 8    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 9    3X52SWXE0YAGFH2TDEP590AM1TNCW4  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 10   34D9ZRXCYSZZFLOM9VJD6GHDVD5SA2  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 11   34D9ZRXCYSZZFLOM9VJD6GHDVD5SA2  3EOS91U1V0GLK8D687GF4TICMDMBYN
# 12   34D9ZRXCYSZZFLOM9VJD6GHDVD5SA2  3EOS91U1V0GLK8D687GF4TICMDMBYN
# ...

# %%
list(rdf2['Answer.comments'])
# Out:
# ['{}',
#  '{}',
#  'none thank you',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'nice',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'super',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'Allow de-selecting the options if selected by mistake',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'It would be useful to know if we can use more than one word in naming.',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'it was fun',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'i loved it',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'Fun!',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'Challenging study!',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  '{}',
#  'very nice task',
#  'was fun',
#  '{}',
#  '{}',
# ...
